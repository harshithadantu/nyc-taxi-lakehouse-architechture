# %% [markdown]
# ####Optimization and zorder  [Optimize -Combines smaller files to bigger files when incremental writes and zorder organizes data in folders so queries run faster ]

# %%
# %sql
optimize databricks_catalog.gold.fact_trip
zorder by ( pu_location_sk, do_location_sk)
